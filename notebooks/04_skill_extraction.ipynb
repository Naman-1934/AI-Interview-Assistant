# %%
import pandas as pd

# %%
resume_df = pd.read_csv("..//data//processed//resume_processed.csv")
resume_df.head()
# Out:
#                                           Resume_str Category  \
# 0           HR ADMINISTRATOR/MARKETING ASSOCIATE\...       HR
# 1           HR SPECIALIST, US HR OPERATIONS      ...       HR
# 2           HR DIRECTOR       Summary      Over 2...       HR
# 3           HR SPECIALIST       Summary    Dedica...       HR
# 4           HR MANAGER         Skill Highlights  ...       HR
#
#                                    clean_resume_text
# 0   hr administrator marketing associate hr admin...
# 1   hr specialist us hr operations summary versat...
# 2   hr director summary over years experience in ...
# 3   hr specialist summary dedicated driven and dy...
# 4   hr manager skill highlights hr skills hr depa...

# %%
from src.skill_extractor.skill_extractor import extract_skills

# %%
resume_df["skills"] = (
    resume_df["clean_resume_text"].apply(extract_skills)
)

resume_df.head()
# Out:
#                                           Resume_str Category  \
# 0           HR ADMINISTRATOR/MARKETING ASSOCIATE\...       HR
# 1           HR SPECIALIST, US HR OPERATIONS      ...       HR
# 2           HR DIRECTOR       Summary      Over 2...       HR
# 3           HR SPECIALIST       Summary    Dedica...       HR
# 4           HR MANAGER         Skill Highlights  ...       HR
#
#                                    clean_resume_text             skills
# 0   hr administrator marketing associate hr admin...  [aws, statistics]
# 1   hr specialist us hr operations summary versat...              [git]
# 2   hr director summary over years experience in ...            [excel]
# 3   hr specialist summary dedicated driven and dy...            [excel]
# 4   hr manager skill highlights hr skills hr depa...       [aws, excel]

# %%
resume_df.to_csv("..//data//processed//resume_with_skills.csv", index=False)
