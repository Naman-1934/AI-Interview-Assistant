# %%
import pandas as pd

# %%
skills_df = pd.read_csv("..//data//master//skills_master.csv")
skills_df.head()
# Out:
#       Skill              Role
# 0    Python    Data Scientist
# 1       Sql      Data Analyst
# 2  Power BI  Business Analyst
# 3     Excel  Business Analyst
# 4   Tableau      Data Analyst

# %%
len(skills_df)
# Out:
# 25
